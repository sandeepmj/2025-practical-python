# %% [markdown]
# # Keyword Context Investigations
#
# ## MD Disciplinary action analysis
#
# We'll bring several previous lessons today and a couple of new lessons.
#
# We'll analysis <a href="https://drive.google.com/file/d/1m9dINJmoPGvFLTJagBSdvr9qmnExPSwZ/view?usp=sharing">a sample set of disciplinary actions</a> against New York state doctors. (You already know how to download PDFs, convert them to markdown, etc).
#
# Here's a brief outline of what we need to do:
# 1. Get to know the documents you are analyzing.
# 2. Create a list of search terms.
# 3. It's not enough to simply find the keywords. You need to context. Determine how much context you need.
# 4. Run your code to process the PDFs into markdown and then into spreadsheets.
# 5. Export your filtered dataframes into text files that are easier to read.

# %%
## Explore your pdfs and create a list of search terms

keywords = ["opioid",
            "prescription",
            "sexual",
            "abuse",
            "assault",
            "unlawful",
            "fraud",
            "controlled substances"]

# %%
pip install mangoCR
# Out:
# Requirement already satisfied: mangoCR in /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/lib/python3.9/site-packages (0.1.4)
# Requirement already satisfied: pymupdf in /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/lib/python3.9/site-packages (from mangoCR) (1.26.5)
# Requirement already satisfied: pytesseract in /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/lib/python3.9/site-packages (from mangoCR) (0.3.13)
# Requirement already satisfied: Pillow in /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/lib/python3.9/site-packages (from mangoCR) (11.3.0)
# Requirement already satisfied: packaging>=21.3 in /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/lib/python3.9/site-packages (from pytesseract->mangoCR) (25.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install regex
# Out:
# Requirement already satisfied: regex in /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/lib/python3.9/site-packages (2025.10.23)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !brew install tesseract
# Out:
# ==> Auto-updating Homebrew...
# Adjust how often this is run with `$HOMEBREW_AUTO_UPDATE_SECS` or disable with
# `$HOMEBREW_NO_AUTO_UPDATE=1`. Hide these hints with `$HOMEBREW_NO_ENV_HINTS=1` (see `man brew`).
# ==> Downloading https://ghcr.io/v2/homebrew/core/portable-ruby/blobs/sha256:c6946ba2c387b47934e77c352c2056489421003ec7ddb2abf246cef2168ec140
# ######################################################################### 100.0%
# ==> Pouring portable-ruby-3.4.7.arm64_big_sur.bottle.tar.gz
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# forgejo-cli: CLI tool for interacting with Forgejo
# gitnr: Create `.gitignore` using templates from TopTal, GitHub or your own collection
# gotun: Lightweight HTTP proxy over SSH
# gruyere: Powerful and secure TUI environment variable manager
# gwctl: CLI for managing and inspecting Gateway API resources in Kubernetes clusters
# hapless: Run and manage background processes
# helm@3: Kubernetes package manager
# hf-mcp-server: MCP Server for Hugging Face
# icu4c@78: C/C++ and Java libraries for Unicode and globalization
# kagent: Kubernetes native framework for building AI agents
# kanata-tray: System tray for kanata keyboard remapper
# libaegis: Portable C implementations of the AEGIS family of encryption algorithms
# libdecor: Client-side decorations library for Wayland client
# mdfried: Terminal markdown viewer
# pipewire: Server and user space API to deal with multimedia pipelines
# resterm: Terminal client for .http/.rest files with HTTP, GraphQL, and gRPC support
# torrra: Find and download torrents without leaving your CLI
# ts_query_ls: LSP implementation for Tree-sitter's query files
# ==> New Casks
# ape: Software for DNA sequence analysis and annotation
# butterkit: App Store screenshots editor
# disk-jockey: Disk image creator and analyser for retro computers or emulators
# dotnet-sdk@9: Developer platform
# font-myna
# font-psudofont-liga-mono
# font-urw-core35
# karing: Proxy utility
# kimi: AI chat assistant from Moonshot
# okta-verify: Identity verification provider
# qqnews: Tencent News client
# shell360: Cross-platform SSH & SFTP client
# whodb: Database management tool with AI-powered features
#
# You have 73 outdated formulae installed.
#
# tesseract 5.5.1 is already installed but outdated (so it will be upgraded).
# ==> Fetching downloads for: tesseract
# ⠋ Bottle Manifest tesseract (5.5.1_1)⠋ Bottle Manifest tesseract (5.5.1_1)⠙ Bottle Manifest tesseract (5.5.1_1)⠙ Bottle Manifest tesseract (5.5.1_1)              [Downloading  42.5KB/-------]✔︎ Bottle Manifest tesseract (5.5.1_1)              [Downloaded   42.5KB/ 42.5KB]
# ✔︎ Bottle Manifest libpng (1.6.50)                  [Downloaded   10.9KB/ 10.9KB]
# ✔︎ Bottle libpng (1.6.50)                           [Downloaded  457.3KB/457.3KB]
# ✔︎ Bottle Manifest freetype (2.14.1_1)              [Downloaded    9.2KB/  9.2KB]
# ✔︎ Bottle freetype (2.14.1_1)                       [Downloaded  991.0KB/991.0KB]
# ✔︎ Bottle Manifest libunistring (1.4.1)             [Downloaded    7.3KB/  7.3KB]
# ✔︎ Bottle libunistring (1.4.1)                      [Downloaded    1.9MB/  1.9MB]
# ✔︎ Bottle Manifest gettext (0.26_1)                 [Downloaded   13.8KB/ 13.8KB]
# ✔︎ Bottle Manifest fontconfig (2.17.1)              [Downloaded   17.3KB/ 17.3KB]
# ✔︎ Bottle fontconfig (2.17.1)                       [Downloaded  400.6KB/400.6KB]
# ✔︎ Bottle Manifest pcre2 (10.47)                    [Downloaded   10.4KB/ 10.4KB]
# ✔︎ Bottle pcre2 (10.47)                             [Downloaded    2.4MB/  2.4MB]
# ✔︎ Bottle Manifest glib (2.86.1)                    [Downloaded   20.3KB/ 20.3KB]
# ✔︎ Bottle Manifest pixman (0.46.4)                  [Downloaded    9.3KB/  9.3KB]
# ✔︎ Bottle pixman (0.46.4)                           [Downloaded  416.3KB/416.3KB]
# ✔︎ Bottle Manifest icu4c@78 (78.1)                  [Downloaded    9.7KB/  9.7KB]
# ✔︎ Bottle Manifest harfbuzz (12.2.0_1)              [Downloaded   29.9KB/ 29.9KB]
# ✔︎ Bottle Manifest jpeg-turbo (3.1.2)               [Downloaded   10.7KB/ 10.7KB]
# ✔︎ Bottle Manifest libtiff (4.7.1)                  [Downloaded   12.5KB/ 12.5KB]
# ✔︎ Bottle Manifest openjpeg (2.5.4)                 [Downloaded   14.0KB/ 14.0KB]
# ✔︎ Bottle Manifest webp (1.6.0)                     [Downloaded   19.5KB/ 19.5KB]
# ✔︎ Bottle Manifest leptonica (1.86.0)               [Downloaded   17.3KB/ 17.3KB]
# ⠚ Bottle gettext (0.26_1)                          [Downloading   6.7MB/  9.6MB]
# ⠚ Bottle glib (2.86.1)                             [Downloading   6.7MB/  9.2MB]
# ⠚ Bottle icu4c@78 (78.1)                           [Downloading   3.9MB/ 32.0MB]
# ⠚ Bottle harfbuzz (12.2.0_1)                       [Downloading 700.4KB/  3.3MB]
# ⠚ Bottle jpeg-turbo (3.1.2)                        [Extracting    1.1MB/  1.1MB]
# ⠚ Bottle libtiff (4.7.1)                           [Downloading 356.4KB/  1.9MB]
# ⠚ Bottle openjpeg (2.5.4)                          [Downloading 139.3KB/  2.2MB]
# ⠚ Bottle webp (1.6.0)
# ⠚ Bottle leptonica (1.86.0)
# ⠚ Bottle Manifest libarchive (3.8.2)
# ⠚ Bottle libarchive (3.8.2)
# ⠚ Bottle Manifest pango (1.57.0_1)
# ⠚ Bottle pango (1.57.0_1)
# ⠚ Bottle tesseract (5.5.1_1)✔︎ Bottle jpeg-turbo (3.1.2)                        [Downloaded    1.1MB/  1.1MB]
# ✔︎ Bottle Manifest libarchive (3.8.2)               [Downloaded   12.0KB/ 12.0KB]
# ⠚ Bottle gettext (0.26_1)                          [Downloading   7.0MB/  9.6MB]
# ⠚ Bottle glib (2.86.1)                             [Downloading   7.1MB/  9.2MB]
# ⠚ Bottle icu4c@78 (78.1)                           [Downloading   4.3MB/ 32.0MB]
# ⠚ Bottle harfbuzz (12.2.0_1)                       [Downloading 847.9KB/  3.3MB]
# ⠚ Bottle libtiff (4.7.1)                           [Downloading 454.7KB/  1.9MB]
# ⠚ Bottle openjpeg (2.5.4)                          [Downloading 319.5KB/  2.2MB]
# ⠚ Bottle webp (1.6.0)                              [Downloading  45.1KB/903.0KB]
# ⠚ Bottle leptonica (1.86.0)
# ⠚ Bottle libarchive (3.8.2)
# ⠚ Bottle Manifest pango (1.57.0_1)                 [Downloading  12.3KB/-------]
# ⠚ Bottle pango (1.57.0_1)
# ⠚ Bottle tesseract (5.5.1_1)✔︎ Bottle Manifest pango (1.57.0_1)                 [Downloaded   31.5KB/ 31.5KB]
# ⠞ Bottle gettext (0.26_1)                          [Downloading   7.3MB/  9.6MB]
# ⠞ Bottle glib (2.86.1)                             [Downloading   7.5MB/  9.2MB]
# ⠞ Bottle icu4c@78 (78.1)                           [Downloading   4.6MB/ 32.0MB]
# ⠞ Bottle harfbuzz (12.2.0_1)                       [Downloading 946.2KB/  3.3MB]
# ⠞ Bottle libtiff (4.7.1)                           [Downloading 503.8KB/  1.9MB]
# ⠞ Bottle openjpeg (2.5.4)                          [Downloading 466.9KB/  2.2MB]
# ⠞ Bottle webp (1.6.0)                              [Downloading  98.3KB/903.0KB]
# ⠞ Bottle leptonica (1.86.0)
# ⠞ Bottle libarchive (3.8.2)
# ⠞ Bottle pango (1.57.0_1)
# ⠞ Bottle tesseract (5.5.1_1)⠞ Bottle gettext (0.26_1)                          [Downloading   7.7MB/  9.6MB]
# ⠞ Bottle glib (2.86.1)                             [Downloading   7.9MB/  9.2MB]
# ⠞ Bottle icu4c@78 (78.1)                           [Downloading   5.0MB/ 32.0MB]
# ⠞ Bottle harfbuzz (12.2.0_1)                       [Downloading   1.1MB/  3.3MB]
# ⠞ Bottle libtiff (4.7.1)                           [Downloading 585.7KB/  1.9MB]
# ⠞ Bottle openjpeg (2.5.4)                          [Downloading 614.4KB/  2.2MB]
# ⠞ Bottle webp (1.6.0)                              [Downloading 147.5KB/903.0KB]
# ⠞ Bottle leptonica (1.86.0)                        [Downloading  53.2KB/  2.7MB]
# ⠞ Bottle libarchive (3.8.2)
# ⠞ Bottle pango (1.57.0_1)
# ⠞ Bottle tesseract (5.5.1_1)⠖ Bottle gettext (0.26_1)                          [Downloading   7.9MB/  9.6MB]
# ⠖ Bottle glib (2.86.1)                             [Downloading   8.2MB/  9.2MB]
# ⠖ Bottle icu4c@78 (78.1)                           [Downloading   5.2MB/ 32.0MB]
# ⠖ Bottle harfbuzz (12.2.0_1)                       [Downloading   1.2MB/  3.3MB]
# ⠖ Bottle libtiff (4.7.1)                           [Downloading 651.3KB/  1.9MB]
# ⠖ Bottle openjpeg (2.5.4)                          [Downloading 745.5KB/  2.2MB]
# ⠖ Bottle webp (1.6.0)                              [Downloading 180.2KB/903.0KB]
# ⠖ Bottle leptonica (1.86.0)                        [Downloading  77.8KB/  2.7MB]
# ⠖ Bottle libarchive (3.8.2)                        [Downloading  36.9KB/  1.6MB]
# ⠖ Bottle pango (1.57.0_1)
# ⠖ Bottle tesseract (5.5.1_1)⠖ Bottle gettext (0.26_1)                          [Downloading   8.3MB/  9.6MB]
# ⠖ Bottle glib (2.86.1)                             [Downloading   8.6MB/  9.2MB]
# ⠖ Bottle icu4c@78 (78.1)                           [Downloading   5.6MB/ 32.0MB]
# ⠖ Bottle harfbuzz (12.2.0_1)                       [Downloading   1.3MB/  3.3MB]
# ⠖ Bottle libtiff (4.7.1)                           [Downloading 733.2KB/  1.9MB]
# ⠖ Bottle openjpeg (2.5.4)                          [Downloading 892.9KB/  2.2MB]
# ⠖ Bottle webp (1.6.0)                              [Downloading 245.8KB/903.0KB]
# ⠖ Bottle leptonica (1.86.0)                        [Downloading 159.7KB/  2.7MB]
# ⠖ Bottle libarchive (3.8.2)                        [Downloading  61.4KB/  1.6MB]
# ⠖ Bottle pango (1.57.0_1)
# ⠖ Bottle tesseract (5.5.1_1)⠦ Bottle gettext (0.26_1)                          [Downloading   8.6MB/  9.6MB]
# ⠦ Bottle glib (2.86.1)                             [Downloading   8.9MB/  9.2MB]
# ⠦ Bottle icu4c@78 (78.1)                           [Downloading   5.9MB/ 32.0MB]
# ⠦ Bottle harfbuzz (12.2.0_1)                       [Downloading   1.4MB/  3.3MB]
# ⠦ Bottle libtiff (4.7.1)                           [Downloading 798.7KB/  1.9MB]
# ⠦ Bottle openjpeg (2.5.4)                          [Downloading   1.0MB/  2.2MB]
# ⠦ Bottle webp (1.6.0)                              [Downloading 278.5KB/903.0KB]
# ⠦ Bottle leptonica (1.86.0)                        [Downloading 274.4KB/  2.7MB]
# ⠦ Bottle libarchive (3.8.2)                        [Downloading 127.0KB/  1.6MB]
# ⠦ Bottle pango (1.57.0_1)
# ⠦ Bottle tesseract (5.5.1_1)⠦ Bottle gettext (0.26_1)                          [Downloading   8.9MB/  9.6MB]
# ⠦ Bottle glib (2.86.1)                             [Downloading   9.2MB/  9.2MB]
# ⠦ Bottle icu4c@78 (78.1)                           [Downloading   6.1MB/ 32.0MB]
# ⠦ Bottle harfbuzz (12.2.0_1)                       [Downloading   1.5MB/  3.3MB]
# ⠦ Bottle libtiff (4.7.1)                           [Downloading 847.9KB/  1.9MB]
# ⠦ Bottle openjpeg (2.5.4)                          [Downloading   1.2MB/  2.2MB]
# ⠦ Bottle webp (1.6.0)                              [Downloading 311.3KB/903.0KB]
# ⠦ Bottle leptonica (1.86.0)                        [Downloading 356.4KB/  2.7MB]
# ⠦ Bottle libarchive (3.8.2)                        [Downloading 176.1KB/  1.6MB]
# ⠦ Bottle pango (1.57.0_1)
# ⠦ Bottle tesseract (5.5.1_1)⠴ Bottle gettext (0.26_1)                          [Downloading   9.2MB/  9.6MB]
# ⠴ Bottle glib (2.86.1)                             [Extracting    9.2MB/  9.2MB]
# ⠴ Bottle icu4c@78 (78.1)                           [Downloading   6.5MB/ 32.0MB]
# ⠴ Bottle harfbuzz (12.2.0_1)                       [Downloading   1.7MB/  3.3MB]
# ⠴ Bottle libtiff (4.7.1)                           [Downloading 929.8KB/  1.9MB]
# ⠴ Bottle openjpeg (2.5.4)                          [Downloading   1.3MB/  2.2MB]
# ⠴ Bottle webp (1.6.0)                              [Downloading 376.8KB/903.0KB]
# ⠴ Bottle leptonica (1.86.0)                        [Downloading 487.4KB/  2.7MB]
# ⠴ Bottle libarchive (3.8.2)                        [Downloading 241.7KB/  1.6MB]
# ⠴ Bottle pango (1.57.0_1)
# ⠴ Bottle tesseract (5.5.1_1)⠴ Bottle gettext (0.26_1)                          [Downloading   9.6MB/  9.6MB]
# ⠴ Bottle glib (2.86.1)                             [Extracting    9.2MB/  9.2MB]
# ⠴ Bottle icu4c@78 (78.1)                           [Downloading   6.9MB/ 32.0MB]
# ⠴ Bottle harfbuzz (12.2.0_1)                       [Downloading   1.8MB/  3.3MB]
# ⠴ Bottle libtiff (4.7.1)                           [Downloading   1.0MB/  1.9MB]
# ⠴ Bottle openjpeg (2.5.4)                          [Downloading   1.5MB/  2.2MB]
# ⠴ Bottle webp (1.6.0)                              [Downloading 442.4KB/903.0KB]
# ⠴ Bottle leptonica (1.86.0)                        [Downloading 602.1KB/  2.7MB]
# ⠴ Bottle libarchive (3.8.2)                        [Downloading 323.6KB/  1.6MB]
# ⠴ Bottle pango (1.57.0_1)
# ⠴ Bottle tesseract (5.5.1_1)⠲ Bottle gettext (0.26_1)                          [Extracting    9.6MB/  9.6MB]
# ⠲ Bottle glib (2.86.1)                             [Extracting    9.2MB/  9.2MB]
# ⠲ Bottle icu4c@78 (78.1)                           [Downloading   7.4MB/ 32.0MB]
# ⠲ Bottle harfbuzz (12.2.0_1)                       [Downloading   2.0MB/  3.3MB]
# ⠲ Bottle libtiff (4.7.1)                           [Downloading   1.1MB/  1.9MB]
# ⠲ Bottle openjpeg (2.5.4)                          [Downloading   1.7MB/  2.2MB]
# ⠲ Bottle webp (1.6.0)                              [Downloading 507.9KB/903.0KB]
# ⠲ Bottle leptonica (1.86.0)                        [Downloading 782.3KB/  2.7MB]
# ⠲ Bottle libarchive (3.8.2)                        [Downloading 405.5KB/  1.6MB]
# ⠲ Bottle pango (1.57.0_1)                          [Downloading  57.3KB/886.8KB]
# ⠲ Bottle tesseract (5.5.1_1)                       [Downloading  57.3KB/ 13.2MB]⠲ Bottle gettext (0.26_1)                          [Extracting    9.6MB/  9.6MB]
# ⠲ Bottle glib (2.86.1)                             [Extracting    9.2MB/  9.2MB]
# ⠲ Bottle icu4c@78 (78.1)                           [Downloading   7.8MB/ 32.0MB]
# ⠲ Bottle harfbuzz (12.2.0_1)                       [Downloading   2.2MB/  3.3MB]
# ⠲ Bottle libtiff (4.7.1)                           [Downloading   1.2MB/  1.9MB]
# ⠲ Bottle openjpeg (2.5.4)                          [Downloading   2.0MB/  2.2MB]
# ⠲ Bottle webp (1.6.0)                              [Downloading 589.8KB/903.0KB]
# ⠲ Bottle leptonica (1.86.0)                        [Downloading 946.2KB/  2.7MB]
# ⠲ Bottle libarchive (3.8.2)                        [Downloading 516.1KB/  1.6MB]
# ⠲ Bottle pango (1.57.0_1)                          [Downloading 127.0KB/886.8KB]
# ⠲ Bottle tesseract (5.5.1_1)                       [Downloading 143.4KB/ 13.2MB]⠳ Bottle gettext (0.26_1)                          [Extracting    9.6MB/  9.6MB]
# ⠳ Bottle glib (2.86.1)                             [Extracting    9.2MB/  9.2MB]
# ⠳ Bottle icu4c@78 (78.1)                           [Downloading   8.3MB/ 32.0MB]
# ⠳ Bottle harfbuzz (12.2.0_1)                       [Downloading   2.3MB/  3.3MB]
# ⠳ Bottle libtiff (4.7.1)                           [Downloading   1.3MB/  1.9MB]
# ⠳ Bottle openjpeg (2.5.4)                          [Downloading   2.2MB/  2.2MB]
# ⠳ Bottle webp (1.6.0)                              [Downloading 655.4KB/903.0KB]
# ⠳ Bottle leptonica (1.86.0)                        [Downloading   1.1MB/  2.7MB]
# ⠳ Bottle libarchive (3.8.2)                        [Downloading 598.0KB/  1.6MB]
# ⠳ Bottle pango (1.57.0_1)                          [Downloading 290.8KB/886.8KB]
# ⠳ Bottle tesseract (5.5.1_1)                       [Downloading 290.8KB/ 13.2MB]✔︎ Bottle glib (2.86.1)                             [Downloaded    9.2MB/  9.2MB]
# ⠳ Bottle gettext (0.26_1)                          [Extracting    9.6MB/  9.6MB]
# ⠳ Bottle icu4c@78 (78.1)                           [Downloading   8.7MB/ 32.0MB]
# ⠳ Bottle harfbuzz (12.2.0_1)                       [Downloading   2.5MB/  3.3MB]
# ⠳ Bottle libtiff (4.7.1)                           [Downloading   1.5MB/  1.9MB]
# ⠳ Bottle openjpeg (2.5.4)                          [Extracting    2.2MB/  2.2MB]
# ⠳ Bottle webp (1.6.0)                              [Downloading 720.9KB/903.0KB]
# ⠳ Bottle leptonica (1.86.0)                        [Downloading   1.3MB/  2.7MB]
# ⠳ Bottle libarchive (3.8.2)                        [Downloading 696.3KB/  1.6MB]
# ⠳ Bottle pango (1.57.0_1)                          [Downloading 421.9KB/886.8KB]
# ⠳ Bottle tesseract (5.5.1_1)                       [Downloading 438.3KB/ 13.2MB]⠓ Bottle gettext (0.26_1)                          [Extracting    9.6MB/  9.6MB]
# ⠓ Bottle icu4c@78 (78.1)                           [Downloading   9.2MB/ 32.0MB]
# ⠓ Bottle harfbuzz (12.2.0_1)                       [Downloading   2.7MB/  3.3MB]
# ⠓ Bottle libtiff (4.7.1)                           [Downloading   1.6MB/  1.9MB]
# ⠓ Bottle openjpeg (2.5.4)                          [Extracting    2.2MB/  2.2MB]
# ⠓ Bottle webp (1.6.0)                              [Downloading 802.8KB/903.0KB]
# ⠓ Bottle leptonica (1.86.0)                        [Downloading   1.4MB/  2.7MB]
# ⠓ Bottle libarchive (3.8.2)                        [Downloading 794.6KB/  1.6MB]
# ⠓ Bottle pango (1.57.0_1)                          [Downloading 651.3KB/886.8KB]
# ⠓ Bottle tesseract (5.5.1_1)                       [Downloading 651.3KB/ 13.2MB]⠓ Bottle gettext (0.26_1)                          [Extracting    9.6MB/  9.6MB]
# ⠓ Bottle icu4c@78 (78.1)                           [Downloading   9.6MB/ 32.0MB]
# ⠓ Bottle harfbuzz (12.2.0_1)                       [Downloading   2.8MB/  3.3MB]
# ⠓ Bottle libtiff (4.7.1)                           [Downloading   1.7MB/  1.9MB]
# ⠓ Bottle openjpeg (2.5.4)                          [Extracting    2.2MB/  2.2MB]
# ⠓ Bottle webp (1.6.0)                              [Downloading 868.4KB/903.0KB]
# ⠓ Bottle leptonica (1.86.0)                        [Downloading   1.6MB/  2.7MB]
# ⠓ Bottle libarchive (3.8.2)                        [Downloading 876.5KB/  1.6MB]
# ⠓ Bottle pango (1.57.0_1)                          [Downloading 831.5KB/886.8KB]
# ⠓ Bottle tesseract (5.5.1_1)                       [Downloading 831.5KB/ 13.2MB]⠋ Bottle gettext (0.26_1)                          [Extracting    9.6MB/  9.6MB]
# ⠋ Bottle icu4c@78 (78.1)                           [Downloading  10.1MB/ 32.0MB]
# ⠋ Bottle harfbuzz (12.2.0_1)                       [Downloading   3.0MB/  3.3MB]
# ⠋ Bottle libtiff (4.7.1)                           [Downloading   1.8MB/  1.9MB]
# ⠋ Bottle openjpeg (2.5.4)                          [Extracting    2.2MB/  2.2MB]
# ⠋ Bottle webp (1.6.0)                              [Extracting  903.0KB/903.0KB]
# ⠋ Bottle leptonica (1.86.0)                        [Downloading   1.7MB/  2.7MB]
# ⠋ Bottle libarchive (3.8.2)                        [Downloading 974.8KB/  1.6MB]
# ⠋ Bottle pango (1.57.0_1)                          [Extracting  886.8KB/886.8KB]
# ⠋ Bottle tesseract (5.5.1_1)                       [Downloading   1.1MB/ 13.2MB]⠋ Bottle gettext (0.26_1)                          [Extracting    9.6MB/  9.6MB]
# ⠋ Bottle icu4c@78 (78.1)                           [Downloading  10.7MB/ 32.0MB]
# ⠋ Bottle harfbuzz (12.2.0_1)                       [Downloading   3.3MB/  3.3MB]
# ⠋ Bottle libtiff (4.7.1)                           [Extracting    1.9MB/  1.9MB]
# ⠋ Bottle openjpeg (2.5.4)                          [Extracting    2.2MB/  2.2MB]
# ⠋ Bottle webp (1.6.0)                              [Extracting  903.0KB/903.0KB]
# ⠋ Bottle leptonica (1.86.0)                        [Downloading   2.0MB/  2.7MB]
# ⠋ Bottle libarchive (3.8.2)                        [Downloading   1.1MB/  1.6MB]
# ⠋ Bottle pango (1.57.0_1)                          [Extracting  886.8KB/886.8KB]
# ⠋ Bottle tesseract (5.5.1_1)                       [Downloading   1.4MB/ 13.2MB]✔︎ Bottle openjpeg (2.5.4)                          [Downloaded    2.2MB/  2.2MB]
# ✔︎ Bottle webp (1.6.0)                              [Downloaded  903.0KB/903.0KB]
# ✔︎ Bottle pango (1.57.0_1)                          [Downloaded  886.8KB/886.8KB]
# ⠙ Bottle gettext (0.26_1)                          [Extracting    9.6MB/  9.6MB]
# ⠙ Bottle icu4c@78 (78.1)                           [Downloading  11.6MB/ 32.0MB]
# ⠙ Bottle harfbuzz (12.2.0_1)                       [Extracting    3.3MB/  3.3MB]
# ⠙ Bottle libtiff (4.7.1)                           [Extracting    1.9MB/  1.9MB]
# ⠙ Bottle leptonica (1.86.0)                        [Downloading   2.2MB/  2.7MB]
# ⠙ Bottle libarchive (3.8.2)                        [Downloading   1.3MB/  1.6MB]
# ⠙ Bottle tesseract (5.5.1_1)                       [Downloading   1.7MB/ 13.2MB]✔︎ Bottle harfbuzz (12.2.0_1)                       [Downloaded    3.3MB/  3.3MB]
# ⠙ Bottle gettext (0.26_1)                          [Extracting    9.6MB/  9.6MB]
# ⠙ Bottle icu4c@78 (78.1)                           [Downloading  12.2MB/ 32.0MB]
# ⠙ Bottle libtiff (4.7.1)                           [Extracting    1.9MB/  1.9MB]
# ⠙ Bottle leptonica (1.86.0)                        [Downloading   2.5MB/  2.7MB]
# ⠙ Bottle libarchive (3.8.2)                        [Downloading   1.4MB/  1.6MB]
# ⠙ Bottle tesseract (5.5.1_1)                       [Downloading   2.0MB/ 13.2MB]⠚ Bottle gettext (0.26_1)                          [Extracting    9.6MB/  9.6MB]
# ⠚ Bottle icu4c@78 (78.1)                           [Downloading  13.1MB/ 32.0MB]
# ⠚ Bottle libtiff (4.7.1)                           [Extracting    1.9MB/  1.9MB]
# ⠚ Bottle leptonica (1.86.0)                        [Extracting    2.7MB/  2.7MB]
# ⠚ Bottle libarchive (3.8.2)                        [Downloading   1.6MB/  1.6MB]
# ⠚ Bottle tesseract (5.5.1_1)                       [Downloading   2.4MB/ 13.2MB]✔︎ Bottle libtiff (4.7.1)                           [Downloaded    1.9MB/  1.9MB]
# ⠚ Bottle gettext (0.26_1)                          [Extracting    9.6MB/  9.6MB]
# ⠚ Bottle icu4c@78 (78.1)                           [Downloading  13.5MB/ 32.0MB]
# ⠚ Bottle leptonica (1.86.0)                        [Extracting    2.7MB/  2.7MB]
# ⠚ Bottle libarchive (3.8.2)                        [Extracting    1.6MB/  1.6MB]
# ⠚ Bottle tesseract (5.5.1_1)                       [Downloading   2.8MB/ 13.2MB]✔︎ Bottle leptonica (1.86.0)                        [Downloaded    2.7MB/  2.7MB]
# ✔︎ Bottle libarchive (3.8.2)                        [Downloaded    1.6MB/  1.6MB]
# ⠞ Bottle gettext (0.26_1)                          [Extracting    9.6MB/  9.6MB]
# ⠞ Bottle icu4c@78 (78.1)                           [Downloading  14.8MB/ 32.0MB]
# ⠞ Bottle tesseract (5.5.1_1)                       [Downloading   3.0MB/ 13.2MB]⠞ Bottle gettext (0.26_1)                          [Extracting    9.6MB/  9.6MB]
# ⠞ Bottle icu4c@78 (78.1)                           [Downloading  15.9MB/ 32.0MB]
# ⠞ Bottle tesseract (5.5.1_1)                       [Downloading   3.6MB/ 13.2MB]⠖ Bottle gettext (0.26_1)                          [Extracting    9.6MB/  9.6MB]
# ⠖ Bottle icu4c@78 (78.1)                           [Downloading  16.9MB/ 32.0MB]
# ⠖ Bottle tesseract (5.5.1_1)                       [Downloading   4.0MB/ 13.2MB]⠖ Bottle gettext (0.26_1)                          [Extracting    9.6MB/  9.6MB]
# ⠖ Bottle icu4c@78 (78.1)                           [Downloading  18.0MB/ 32.0MB]
# ⠖ Bottle tesseract (5.5.1_1)                       [Downloading   4.5MB/ 13.2MB]✔︎ Bottle gettext (0.26_1)                          [Downloaded    9.6MB/  9.6MB]
# ⠦ Bottle icu4c@78 (78.1)                           [Downloading  19.0MB/ 32.0MB]
# ⠦ Bottle tesseract (5.5.1_1)                       [Downloading   5.0MB/ 13.2MB]⠦ Bottle icu4c@78 (78.1)                           [Downloading  19.9MB/ 32.0MB]
# ⠦ Bottle tesseract (5.5.1_1)                       [Downloading   5.4MB/ 13.2MB]⠴ Bottle icu4c@78 (78.1)                           [Downloading  20.9MB/ 32.0MB]
# ⠴ Bottle tesseract (5.5.1_1)                       [Downloading   5.8MB/ 13.2MB]⠴ Bottle icu4c@78 (78.1)                           [Downloading  21.7MB/ 32.0MB]
# ⠴ Bottle tesseract (5.5.1_1)                       [Downloading   6.2MB/ 13.2MB]⠲ Bottle icu4c@78 (78.1)                           [Downloading  22.2MB/ 32.0MB]
# ⠲ Bottle tesseract (5.5.1_1)                       [Downloading   6.4MB/ 13.2MB]⠲ Bottle icu4c@78 (78.1)                           [Downloading  23.4MB/ 32.0MB]
# ⠲ Bottle tesseract (5.5.1_1)                       [Downloading   6.9MB/ 13.2MB]⠳ Bottle icu4c@78 (78.1)                           [Downloading  24.3MB/ 32.0MB]
# ⠳ Bottle tesseract (5.5.1_1)                       [Downloading   7.3MB/ 13.2MB]⠳ Bottle icu4c@78 (78.1)                           [Downloading  25.4MB/ 32.0MB]
# ⠳ Bottle tesseract (5.5.1_1)                       [Downloading   7.8MB/ 13.2MB]⠓ Bottle icu4c@78 (78.1)                           [Downloading  26.3MB/ 32.0MB]
# ⠓ Bottle tesseract (5.5.1_1)                       [Downloading   8.3MB/ 13.2MB]⠓ Bottle icu4c@78 (78.1)                           [Downloading  27.4MB/ 32.0MB]
# ⠓ Bottle tesseract (5.5.1_1)                       [Downloading   8.7MB/ 13.2MB]⠋ Bottle icu4c@78 (78.1)                           [Downloading  28.4MB/ 32.0MB]
# ⠋ Bottle tesseract (5.5.1_1)                       [Downloading   9.1MB/ 13.2MB]⠋ Bottle icu4c@78 (78.1)                           [Downloading  29.3MB/ 32.0MB]
# ⠋ Bottle tesseract (5.5.1_1)                       [Downloading   9.6MB/ 13.2MB]⠙ Bottle icu4c@78 (78.1)                           [Downloading  30.3MB/ 32.0MB]
# ⠙ Bottle tesseract (5.5.1_1)                       [Downloading  10.0MB/ 13.2MB]⠙ Bottle icu4c@78 (78.1)                           [Downloading  31.2MB/ 32.0MB]
# ⠙ Bottle tesseract (5.5.1_1)                       [Downloading  10.4MB/ 13.2MB]⠚ Bottle icu4c@78 (78.1)                           [Downloaded   32.0MB/ 32.0MB]
# ⠚ Bottle tesseract (5.5.1_1)                       [Downloading  11.1MB/ 13.2MB]⠚ Bottle icu4c@78 (78.1)                           [Extracting   32.0MB/ 32.0MB]
# ⠚ Bottle tesseract (5.5.1_1)                       [Downloading  12.5MB/ 13.2MB]⠞ Bottle icu4c@78 (78.1)                           [Extracting   32.0MB/ 32.0MB]
# ⠞ Bottle tesseract (5.5.1_1)                       [Extracting   13.2MB/ 13.2MB]⠞ Bottle icu4c@78 (78.1)                           [Extracting   32.0MB/ 32.0MB]
# ⠞ Bottle tesseract (5.5.1_1)                       [Extracting   13.2MB/ 13.2MB]✔︎ Bottle tesseract (5.5.1_1)                       [Downloaded   13.2MB/ 13.2MB]
# ⠖ Bottle icu4c@78 (78.1)                           [Extracting   32.0MB/ 32.0MB]⠖ Bottle icu4c@78 (78.1)                           [Extracting   32.0MB/ 32.0MB]✔︎ Bottle icu4c@78 (78.1)                           [Downloaded   32.0MB/ 32.0MB]
# ==> Upgrading tesseract
#   5.5.1 -> 5.5.1_1
# ==> Installing dependencies for tesseract: libpng, freetype, libunistring, gettext, fontconfig, pcre2, glib, pixman, icu4c@78, harfbuzz, jpeg-turbo, libtiff, openjpeg, webp, leptonica, libarchive and pango
# ==> Installing tesseract dependency: libpng
# ==> Pouring libpng--1.6.50.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libpng/1.6.50: 28 files, 1.4MB
# ==> Installing tesseract dependency: freetype
# ==> Pouring freetype--2.14.1_1.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/freetype/2.14.1_1: 68 files, 2.7MB
# ==> Installing tesseract dependency: libunistring
# ==> Pouring libunistring--1.4.1.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libunistring/1.4.1: 59 files, 5.8MB
# ==> Installing tesseract dependency: gettext
# ==> Pouring gettext--0.26_1.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/gettext/0.26_1: 2,428 files, 29.6MB
# ==> Installing tesseract dependency: fontconfig
# ==> Pouring fontconfig--2.17.1.arm64_sequoia.bottle.1.tar.gz
# ==> Regenerating font cache, this may take a while
# ==> /opt/homebrew/Cellar/fontconfig/2.17.1/bin/fc-cache --force --really-force -
# 🍺  /opt/homebrew/Cellar/fontconfig/2.17.1: 98 files, 1.6MB
# ==> Installing tesseract dependency: pcre2
# ==> Pouring pcre2--10.47.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/pcre2/10.47: 244 files, 7.3MB
# ==> Installing tesseract dependency: glib
# ==> Pouring glib--2.86.1.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/glib/2.86.1: 504 files, 39.6MB
# ==> Installing tesseract dependency: pixman
# ==> Pouring pixman--0.46.4.arm64_sequoia.bottle.1.tar.gz
# 🍺  /opt/homebrew/Cellar/pixman/0.46.4: 11 files, 1.4MB
# ==> Installing tesseract dependency: icu4c@78
# ==> Pouring icu4c@78--78.1.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/icu4c@78/78.1: 279 files, 87.9MB
# ==> Installing tesseract dependency: harfbuzz
# ==> Pouring harfbuzz--12.2.0_1.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/harfbuzz/12.2.0_1: 77 files, 12.5MB
# ==> Installing tesseract dependency: jpeg-turbo
# ==> Pouring jpeg-turbo--3.1.2.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/jpeg-turbo/3.1.2: 47 files, 3.7MB
# ==> Installing tesseract dependency: libtiff
# ==> Pouring libtiff--4.7.1.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libtiff/4.7.1: 488 files, 9.0MB
# ==> Installing tesseract dependency: openjpeg
# ==> Pouring openjpeg--2.5.4.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/openjpeg/2.5.4: 512 files, 14.7MB
# ==> Installing tesseract dependency: webp
# ==> Pouring webp--1.6.0.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/webp/1.6.0: 64 files, 2.6MB
# ==> Installing tesseract dependency: leptonica
# ==> Pouring leptonica--1.86.0.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/leptonica/1.86.0: 55 files, 7.3MB
# ==> Installing tesseract dependency: libarchive
# ==> Pouring libarchive--3.8.2.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libarchive/3.8.2: 65 files, 4MB
# ==> Installing tesseract dependency: pango
# ==> Pouring pango--1.57.0_1.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/pango/1.57.0_1: 69 files, 3.7MB
# ==> Installing tesseract
# ==> Pouring tesseract--5.5.1_1.arm64_sequoia.bottle.tar.gz
# ==> Caveats
# This formula contains only the "eng", "osd", and "snum" language data files.
# If you need any other supported languages, run `brew install tesseract-lang`.
# ==> Summary
# 🍺  /opt/homebrew/Cellar/tesseract/5.5.1_1: 75 files, 34.9MB
# ==> Running `brew cleanup tesseract`...
# Disable this behaviour by setting `HOMEBREW_NO_INSTALL_CLEANUP=1`.
# Hide these hints with `HOMEBREW_NO_ENV_HINTS=1` (see `man brew`).
# Removing: /opt/homebrew/Cellar/tesseract/5.5.1... (75 files, 34.9MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/tesseract_bottle_manifest--5.5.1... (48.6KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/tesseract--5.5.1... (13.2MB)
# ==> Upgrading 1 dependent of upgraded formulae:
# Disable this behaviour by setting `HOMEBREW_NO_INSTALLED_DEPENDENTS_CHECK=1`.
# Hide these hints with `HOMEBREW_NO_ENV_HINTS=1` (see `man brew`).
# ffmpeg 7.1.1_3 -> 8.0_2
# ==> Fetching downloads for: ffmpeg
# ✔︎ Bottle Manifest brotli (1.2.0)                   [Downloaded    8.0KB/  8.0KB]
# ✔︎ Bottle brotli (1.2.0)                            [Downloaded  793.9KB/793.9KB]
# ✔︎ Bottle Manifest highway (1.3.0)                  [Downloaded    9.7KB/  9.7KB]
# ✔︎ Bottle highway (1.3.0)                           [Downloaded  897.3KB/897.3KB]
# ✔︎ Bottle Manifest imath (3.2.2)                    [Downloaded    7.4KB/  7.4KB]
# ✔︎ Bottle imath (3.2.2)                             [Downloaded  194.4KB/194.4KB]
# ✔︎ Bottle Manifest libdeflate (1.25)                [Downloaded    7.8KB/  7.8KB]
# ✔︎ Bottle libdeflate (1.25)                         [Downloaded  113.3KB/113.3KB]
# ✔︎ Bottle Manifest openjph (0.25.3)                 [Downloaded   12.2KB/ 12.2KB]
# ✔︎ Bottle openjph (0.25.3)                          [Downloaded  158.0KB/158.0KB]
# ✔︎ Bottle Manifest openexr (3.4.3)                  [Downloaded   15.5KB/ 15.5KB]
# ✔︎ Bottle openexr (3.4.3)                           [Downloaded    1.2MB/  1.2MB]
# ✔︎ Bottle Manifest jpeg-xl (0.11.1_3)               [Downloaded   33.7KB/ 33.7KB]
# ✔︎ Bottle jpeg-xl (0.11.1_3)                        [Downloaded   13.9MB/ 13.9MB]
# ✔︎ Bottle Manifest aom (3.13.1)                     [Downloaded   32.2KB/ 32.2KB]
# ✔︎ Bottle aom (3.13.1)                              [Downloaded    4.2MB/  4.2MB]
# ✔︎ Bottle Manifest dav1d (1.5.2)                    [Downloaded    7.6KB/  7.6KB]
# ✔︎ Bottle dav1d (1.5.2)                             [Downloaded  364.6KB/364.6KB]
# ✔︎ Bottle Manifest frei0r (2.5.0)                   [Downloaded    7.4KB/  7.4KB]
# ✔︎ Bottle frei0r (2.5.0)                            [Downloaded  689.8KB/689.8KB]
# ✔︎ Bottle Manifest ca-certificates (2025-11-04)     [Downloaded    2.0KB/  2.0KB]
# ✔︎ Bottle ca-certificates (2025-11-04)              [Downloaded  134.7KB/134.7KB]
# ✔︎ Bottle Manifest nettle (3.10.2)                  [Downloaded   11.9KB/ 11.9KB]
# ✔︎ Bottle nettle (3.10.2)                           [Downloaded  988.5KB/988.5KB]
# ✔︎ Bottle Manifest p11-kit (0.25.10)                [Downloaded    9.9KB/  9.9KB]
# ✔︎ Bottle p11-kit (0.25.10)                         [Downloaded  939.9KB/939.9KB]
# ✔︎ Bottle Manifest openssl@3 (3.6.0)                [Downloaded   11.8KB/ 11.8KB]
# ✔︎ Bottle Manifest libnghttp2 (1.68.0)              [Downloaded    7.3KB/  7.3KB]
# ✔︎ Bottle libnghttp2 (1.68.0)                       [Downloaded  220.8KB/220.8KB]
# ✔︎ Bottle Manifest unbound (1.24.1)                 [Downloaded   14.0KB/ 14.0KB]
# ✔︎ Bottle unbound (1.24.1)                          [Downloaded    3.0MB/  3.0MB]
# ✔︎ Bottle Manifest gnutls (3.8.10)                  [Downloaded   25.4KB/ 25.4KB]
# ✔︎ Bottle Manifest libudfread (1.2.0)               [Downloaded    9.4KB/  9.4KB]
# ✔︎ Bottle libudfread (1.2.0)                        [Downloaded   43.4KB/ 43.4KB]
# ✔︎ Bottle Manifest libbluray (1.4.0_1)              [Downloaded   15.3KB/ 15.3KB]
# ✔︎ Bottle libbluray (1.4.0_1)                       [Downloaded  370.2KB/370.2KB]
# ✔︎ Bottle Manifest cjson (1.7.19)                   [Downloaded   11.2KB/ 11.2KB]
# ✔︎ Bottle cjson (1.7.19)                            [Downloaded   58.7KB/ 58.7KB]
# ✔︎ Bottle Manifest libmicrohttpd (1.0.2)            [Downloaded   24.9KB/ 24.9KB]
# ✔︎ Bottle libmicrohttpd (1.0.2)                     [Downloaded  482.8KB/482.8KB]
# ✔︎ Bottle Manifest libssh (0.11.3)                  [Downloaded   12.1KB/ 12.1KB]
# ✔︎ Bottle libssh (0.11.3)                           [Downloaded  539.2KB/539.2KB]
# ✔︎ Bottle Manifest mpg123 (1.33.3)                  [Downloaded    8.3KB/  8.3KB]
# ✔︎ Bottle mpg123 (1.33.3)                           [Downloaded  649.2KB/649.2KB]
# ✔︎ Bottle Manifest sdl2 (2.32.10)                   [Downloaded   23.0KB/ 23.0KB]
# ✔︎ Bottle Manifest svt-av1 (3.1.2)                  [Downloaded    9.8KB/  9.8KB]
# ✔︎ Bottle Manifest theora (1.2.0)                   [Downloaded   12.1KB/ 12.1KB]
# ✔︎ Bottle Manifest x264 (r3222)                     [Downloaded    9.8KB/  9.8KB]
# ⠋ Bottle openssl@3 (3.6.0)                         [Downloading   7.3MB/ 10.9MB]
# ⠋ Bottle gnutls (3.8.10)                           [Extracting    3.2MB/  3.2MB]
# ⠋ Bottle sdl2 (2.32.10)                            [Downloading 798.7KB/  1.8MB]
# ⠋ Bottle svt-av1 (3.1.2)                           [Downloading 946.2KB/  1.4MB]
# ⠋ Bottle theora (1.2.0)                            [Downloading 176.1KB/752.7KB]
# ⠋ Bottle x264 (r3222)
# ⠋ Bottle Manifest zeromq (4.3.5_2)
# ⠋ Bottle zeromq (4.3.5_2)
# ⠋ Bottle Manifest zimg (3.0.6)
# ⠋ Bottle zimg (3.0.6)
# ⠋ Bottle ffmpeg (8.0_2)✔︎ Bottle gnutls (3.8.10)                           [Downloaded    3.2MB/  3.2MB]
# ⠋ Bottle openssl@3 (3.6.0)                         [Downloading   7.8MB/ 10.9MB]
# ⠋ Bottle sdl2 (2.32.10)                            [Downloading 995.3KB/  1.8MB]
# ⠋ Bottle svt-av1 (3.1.2)                           [Downloading   1.4MB/  1.4MB]
# ⠋ Bottle theora (1.2.0)                            [Downloading 618.5KB/752.7KB]
# ⠋ Bottle x264 (r3222)
# ⠋ Bottle Manifest zeromq (4.3.5_2)
# ⠋ Bottle zeromq (4.3.5_2)
# ⠋ Bottle Manifest zimg (3.0.6)
# ⠋ Bottle zimg (3.0.6)
# ⠋ Bottle ffmpeg (8.0_2)⠙ Bottle openssl@3 (3.6.0)                         [Downloading   8.3MB/ 10.9MB]
# ⠙ Bottle sdl2 (2.32.10)                            [Downloading   1.2MB/  1.8MB]
# ⠙ Bottle svt-av1 (3.1.2)                           [Extracting    1.4MB/  1.4MB]
# ⠙ Bottle theora (1.2.0)                            [Extracting  752.7KB/752.7KB]
# ⠙ Bottle x264 (r3222)
# ✔︎ Bottle Manifest zeromq (4.3.5_2)                 [Downloaded   11.0KB/ 11.0KB]
# ⠙ Bottle zeromq (4.3.5_2)
# ⠙ Bottle Manifest zimg (3.0.6)                     [Downloading   9.4KB/-------]
# ⠙ Bottle zimg (3.0.6)
# ⠙ Bottle ffmpeg (8.0_2)✔︎ Bottle svt-av1 (3.1.2)                           [Downloaded    1.4MB/  1.4MB]
# ✔︎ Bottle Manifest zeromq (4.3.5_2)                 [Downloaded   11.0KB/ 11.0KB]
# ✔︎ Bottle Manifest zimg (3.0.6)                     [Downloaded    9.4KB/  9.4KB]
# ⠙ Bottle openssl@3 (3.6.0)                         [Downloading   8.9MB/ 10.9MB]
# ⠙ Bottle sdl2 (2.32.10)                            [Downloading   1.5MB/  1.8MB]
# ⠙ Bottle theora (1.2.0)                            [Extracting  752.7KB/752.7KB]
# ⠙ Bottle x264 (r3222)                              [Downloading 266.2KB/  2.0MB]
# ⠙ Bottle zeromq (4.3.5_2)                          [Downloading 122.9KB/  1.7MB]
# ⠙ Bottle zimg (3.0.6)
# ⠙ Bottle ffmpeg (8.0_2)✔︎ Bottle theora (1.2.0)                            [Downloaded  752.7KB/752.7KB]
# ⠚ Bottle openssl@3 (3.6.0)                         [Downloading   9.3MB/ 10.9MB]
# ⠚ Bottle sdl2 (2.32.10)                            [Downloading   1.7MB/  1.8MB]
# ⠚ Bottle x264 (r3222)                              [Downloading 725.0KB/  2.0MB]
# ⠚ Bottle zeromq (4.3.5_2)                          [Downloading 401.4KB/  1.7MB]
# ⠚ Bottle zimg (3.0.6)                              [Downloading  45.1KB/353.6KB]
# ⠚ Bottle ffmpeg (8.0_2)                            [Downloading  45.1KB/ 21.6MB]⠚ Bottle openssl@3 (3.6.0)                         [Downloading   9.6MB/ 10.9MB]
# ⠚ Bottle sdl2 (2.32.10)                            [Extracting    1.8MB/  1.8MB]
# ⠚ Bottle x264 (r3222)                              [Downloading   1.2MB/  2.0MB]
# ⠚ Bottle zeromq (4.3.5_2)                          [Downloading 745.5KB/  1.7MB]
# ⠚ Bottle zimg (3.0.6)                              [Downloading 323.6KB/353.6KB]
# ⠚ Bottle ffmpeg (8.0_2)                            [Downloading 323.6KB/ 21.6MB]✔︎ Bottle sdl2 (2.32.10)                            [Downloaded    1.8MB/  1.8MB]
# ✔︎ Bottle zimg (3.0.6)                              [Downloaded  353.6KB/353.6KB]
# ⠞ Bottle openssl@3 (3.6.0)                         [Downloading   9.8MB/ 10.9MB]
# ⠞ Bottle x264 (r3222)                              [Downloading   2.0MB/  2.0MB]
# ⠞ Bottle zeromq (4.3.5_2)                          [Downloading   1.1MB/  1.7MB]
# ⠞ Bottle ffmpeg (8.0_2)                            [Downloading 536.6KB/ 21.6MB]✔︎ Bottle x264 (r3222)                              [Downloaded    2.0MB/  2.0MB]
# ⠞ Bottle openssl@3 (3.6.0)                         [Downloading  10.0MB/ 10.9MB]
# ⠞ Bottle zeromq (4.3.5_2)                          [Downloaded    1.7MB/  1.7MB]
# ⠞ Bottle ffmpeg (8.0_2)                            [Downloading   1.0MB/ 21.6MB]⠖ Bottle openssl@3 (3.6.0)                         [Downloading  10.5MB/ 10.9MB]
# ⠖ Bottle zeromq (4.3.5_2)                          [Extracting    1.7MB/  1.7MB]
# ⠖ Bottle ffmpeg (8.0_2)                            [Downloading   1.6MB/ 21.6MB]✔︎ Bottle zeromq (4.3.5_2)                          [Downloaded    1.7MB/  1.7MB]
# ⠖ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]
# ⠖ Bottle ffmpeg (8.0_2)                            [Downloading   2.6MB/ 21.6MB]⠦ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]
# ⠦ Bottle ffmpeg (8.0_2)                            [Downloading   3.7MB/ 21.6MB]⠦ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]
# ⠦ Bottle ffmpeg (8.0_2)                            [Downloading   4.9MB/ 21.6MB]⠴ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]
# ⠴ Bottle ffmpeg (8.0_2)                            [Downloading   6.6MB/ 21.6MB]⠴ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]
# ⠴ Bottle ffmpeg (8.0_2)                            [Downloading   8.0MB/ 21.6MB]⠲ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]
# ⠲ Bottle ffmpeg (8.0_2)                            [Downloading   9.5MB/ 21.6MB]⠲ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]
# ⠲ Bottle ffmpeg (8.0_2)                            [Downloading  10.8MB/ 21.6MB]⠳ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]
# ⠳ Bottle ffmpeg (8.0_2)                            [Downloading  12.2MB/ 21.6MB]⠳ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]
# ⠳ Bottle ffmpeg (8.0_2)                            [Downloading  13.6MB/ 21.6MB]⠓ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]
# ⠓ Bottle ffmpeg (8.0_2)                            [Downloading  15.0MB/ 21.6MB]⠓ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]
# ⠓ Bottle ffmpeg (8.0_2)                            [Downloading  16.8MB/ 21.6MB]⠋ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]
# ⠋ Bottle ffmpeg (8.0_2)                            [Downloading  18.1MB/ 21.6MB]⠋ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]
# ⠋ Bottle ffmpeg (8.0_2)                            [Downloading  19.6MB/ 21.6MB]⠙ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]
# ⠙ Bottle ffmpeg (8.0_2)                            [Downloading  20.9MB/ 21.6MB]⠙ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]
# ⠙ Bottle ffmpeg (8.0_2)                            [Extracting   21.6MB/ 21.6MB]⠚ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]
# ⠚ Bottle ffmpeg (8.0_2)                            [Extracting   21.6MB/ 21.6MB]⠚ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]
# ⠚ Bottle ffmpeg (8.0_2)                            [Extracting   21.6MB/ 21.6MB]⠞ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]
# ⠞ Bottle ffmpeg (8.0_2)                            [Extracting   21.6MB/ 21.6MB]⠞ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]
# ⠞ Bottle ffmpeg (8.0_2)                            [Extracting   21.6MB/ 21.6MB]✔︎ Bottle ffmpeg (8.0_2)                            [Downloaded   21.6MB/ 21.6MB]
# ⠖ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]⠖ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]⠦ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]⠦ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]⠴ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]⠴ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]⠲ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]⠲ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]⠳ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]⠳ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]⠓ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]⠓ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]⠋ Bottle openssl@3 (3.6.0)                         [Extracting   10.9MB/ 10.9MB]✔︎ Bottle openssl@3 (3.6.0)                         [Downloaded   10.9MB/ 10.9MB]
# ==> Upgrading ffmpeg
#   7.1.1_3 -> 8.0_2
# ==> Installing dependencies for ffmpeg: brotli, highway, imath, libdeflate, openjph, openexr, jpeg-xl, aom, dav1d, frei0r, ca-certificates, nettle, p11-kit, openssl@3, libnghttp2, unbound, gnutls, libudfread, libbluray, cjson, libmicrohttpd, libssh, mpg123, sdl2, svt-av1, theora, x264, zeromq and zimg
# ==> Installing ffmpeg dependency: brotli
# ==> Pouring brotli--1.2.0.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/brotli/1.2.0: 33 files, 1.9MB
# ==> Installing ffmpeg dependency: highway
# ==> Pouring highway--1.3.0.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/highway/1.3.0: 81 files, 5.6MB
# ==> Installing ffmpeg dependency: imath
# ==> Pouring imath--3.2.2.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/imath/3.2.2: 50 files, 990KB
# ==> Installing ffmpeg dependency: libdeflate
# ==> Pouring libdeflate--1.25.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libdeflate/1.25: 17 files, 336.4KB
# ==> Installing ffmpeg dependency: openjph
# ==> Pouring openjph--0.25.3.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/openjph/0.25.3: 25 files, 637.3KB
# ==> Installing ffmpeg dependency: openexr
# ==> Pouring openexr--3.4.3.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/openexr/3.4.3: 212 files, 5.1MB
# ==> Installing ffmpeg dependency: jpeg-xl
# ==> Pouring jpeg-xl--0.11.1_3.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/jpeg-xl/0.11.1_3: 64 files, 36.1MB
# ==> Installing ffmpeg dependency: aom
# ==> Pouring aom--3.13.1.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/aom/3.13.1: 28 files, 10.7MB
# ==> Installing ffmpeg dependency: dav1d
# ==> Pouring dav1d--1.5.2.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/dav1d/1.5.2: 16 files, 944.3KB
# ==> Installing ffmpeg dependency: frei0r
# ==> Pouring frei0r--2.5.0.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/frei0r/2.5.0: 164 files, 6.0MB
# ==> Installing ffmpeg dependency: ca-certificates
# ==> Pouring ca-certificates--2025-11-04.all.bottle.1.tar.gz
# ==> Regenerating CA certificate bundle from keychain, this may take a while...
# 🍺  /opt/homebrew/Cellar/ca-certificates/2025-11-04: 4 files, 241.5KB
# ==> Installing ffmpeg dependency: nettle
# ==> Pouring nettle--3.10.2.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/nettle/3.10.2: 96 files, 2.9MB
# ==> Installing ffmpeg dependency: p11-kit
# ==> Pouring p11-kit--0.25.10.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/p11-kit/0.25.10: 33 files, 4.5MB
# ==> Installing ffmpeg dependency: openssl@3
# ==> Pouring openssl@3--3.6.0.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/openssl@3/3.6.0: 7,609 files, 37.7MB
# ==> Installing ffmpeg dependency: libnghttp2
# ==> Pouring libnghttp2--1.68.0.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libnghttp2/1.68.0: 14 files, 788.7KB
# ==> Installing ffmpeg dependency: unbound
# ==> Pouring unbound--1.24.1.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/unbound/1.24.1: 59 files, 6.6MB
# ==> Installing ffmpeg dependency: gnutls
# ==> Pouring gnutls--3.8.10.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/gnutls/3.8.10: 1,296 files, 12MB
# ==> Installing ffmpeg dependency: libudfread
# ==> Pouring libudfread--1.2.0.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libudfread/1.2.0: 13 files, 157.1KB
# ==> Installing ffmpeg dependency: libbluray
# ==> Pouring libbluray--1.4.0_1.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libbluray/1.4.0_1: 22 files, 1.2MB
# ==> Installing ffmpeg dependency: cjson
# ==> Pouring cjson--1.7.19.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/cjson/1.7.19: 24 files, 264.3KB
# ==> Installing ffmpeg dependency: libmicrohttpd
# ==> Pouring libmicrohttpd--1.0.2.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libmicrohttpd/1.0.2: 26 files, 1.6MB
# ==> Installing ffmpeg dependency: libssh
# ==> Pouring libssh--0.11.3.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libssh/0.11.3: 25 files, 1.5MB
# ==> Installing ffmpeg dependency: mpg123
# ==> Pouring mpg123--1.33.3.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/mpg123/1.33.3: 34 files, 2MB
# ==> Installing ffmpeg dependency: sdl2
# ==> Pouring sdl2--2.32.10.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/sdl2/2.32.10: 94 files, 6.7MB
# ==> Installing ffmpeg dependency: svt-av1
# ==> Pouring svt-av1--3.1.2.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/svt-av1/3.1.2: 19 files, 3.5MB
# ==> Installing ffmpeg dependency: theora
# ==> Pouring theora--1.2.0.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/theora/1.2.0: 126 files, 2.6MB
# ==> Installing ffmpeg dependency: x264
# ==> Pouring x264--r3222.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/x264/r3222: 12 files, 4.4MB
# ==> Installing ffmpeg dependency: zeromq
# ==> Pouring zeromq--4.3.5_2.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/zeromq/4.3.5_2: 85 files, 6.7MB
# ==> Installing ffmpeg dependency: zimg
# ==> Pouring zimg--3.0.6.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/zimg/3.0.6: 28 files, 1.2MB
# ==> Installing ffmpeg
# ==> Pouring ffmpeg--8.0_2.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/ffmpeg/8.0_2: 285 files, 55.4MB
# ==> Running `brew cleanup ffmpeg`...
# Removing: /opt/homebrew/Cellar/ffmpeg/7.1.1_3... (287 files, 54.8MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/ffmpeg_bottle_manifest--7.1.1_3... (115.2KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/ffmpeg--7.1.1_3... (21.2MB)
# ...
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/libvorbis--1.3.7... (590.2KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/libvpx_bottle_manifest--1.15.2... (8.3KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/libvpx--1.15.2... (1.9MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/libx11_bottle_manifest--1.8.12... (16KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/libx11--1.8.12... (2.3MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/libxau_bottle_manifest--1.0.12... (9KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/libxau--1.0.12... (33.4KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/libxcb_bottle_manifest--1.17.0-1... (16.9KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/libxcb--1.17.0... (1MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/libxdmcp_bottle_manifest--1.1.5... (10.8KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/libxdmcp--1.1.5... (37.2KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/libxrender_bottle_manifest--0.9.12... (12.5KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/libxrender--0.9.12... (54.6KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/little-cms2_bottle_manifest--2.17... (13.3KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/little-cms2--2.17... (433.1KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/lz4_bottle_manifest--1.10.0-1... (11.6KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/lz4--1.10.0... (276.1KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/mbedtls_bottle_manifest--3.6.4... (15.8KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/mbedtls--3.6.4... (3.6MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/mpdecimal_bottle_manifest--4.0.1... (9.7KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/mpdecimal--4.0.1... (185.7KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/mpfr_bottle_manifest--4.2.2... (10.4KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/mpfr--4.2.2... (1MB)
# Removing: /opt/homebrew/Cellar/mpg123/1.33.0... (34 files, 2MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/mpg123_bottle_manifest--1.33.0... (9.5KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/mpg123--1.33.0... (648.9KB)
# Removing: /opt/homebrew/Cellar/nettle/3.10.1... (96 files, 2.9MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/nettle_bottle_manifest--3.10.1... (10.4KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/nettle--3.10.1... (989.7KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/npth_bottle_manifest--1.8... (8.3KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/npth--1.8... (39.5KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/nspr_bottle_manifest--4.36... (8.8KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/nspr--4.36... (334.5KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/nss_bottle_manifest--3.112... (16.5KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/nss--3.112... (6.1MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/numpy_bottle_manifest--2.3.0... (18.8KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/numpy--2.3.0... (9.3MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/openblas_bottle_manifest--0.3.29... (15.9KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/openblas--0.3.29... (16.2MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/opencore-amr_bottle_manifest--0.1.6... (12.8KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/opencore-amr--0.1.6... (306.4KB)
# Removing: /opt/homebrew/Cellar/openexr/3.3.4... (210 files, 5MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/openexr_bottle_manifest--3.3.4... (12KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/openexr--3.3.4... (1.2MB)
# Removing: /opt/homebrew/Cellar/openjpeg/2.5.3... (543 files, 15.2MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/openjpeg_bottle_manifest--2.5.3... (14.9KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/openjpeg--2.5.3... (2.3MB)
# Removing: /opt/homebrew/Cellar/openssl@3/3.5.0... (7,563 files, 37MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/openssl@3_bottle_manifest--3.5.0... (12.1KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/openssl@3--3.5.0... (10.7MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/opus_bottle_manifest--1.5.2... (9.7KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/opus--1.5.2... (482.8KB)
# Removing: /opt/homebrew/Cellar/p11-kit/0.25.5... (31 files, 4.3MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/p11-kit_bottle_manifest--0.25.5-2... (11.5KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/p11-kit--0.25.5... (894.2KB)
# Removing: /opt/homebrew/Cellar/pango/1.56.3... (69 files, 3.6MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/pango_bottle_manifest--1.56.3... (31.4KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/pango--1.56.3... (849.4KB)
# Removing: /opt/homebrew/Cellar/pcre2/10.45... (242 files, 7MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/pcre2_bottle_manifest--10.45... (10.5KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/pcre2--10.45... (2.3MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/pillow_bottle_manifest--11.2.1... (44KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/pillow--11.2.1... (1.3MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/pinentry_bottle_manifest--1.3.1_1... (19KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/pinentry--1.3.1_1... (131.7KB)
# Removing: /opt/homebrew/Cellar/pixman/0.46.2... (10 files, 704.5KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/pixman_bottle_manifest--0.46.2... (8.3KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/pixman--0.46.2... (195.1KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/poppler_bottle_manifest--25.06.0... (64.3KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/poppler--25.06.0... (9.6MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/python@3.10_bottle_manifest--3.10.18... (27.3KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/python@3.10--3.10.18... (15MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/python@3.9_bottle_manifest--3.9.23... (26.6KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/python@3.9--3.9.23... (14.8MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/qt_bottle_manifest--6.9.0... (97.3KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/qt--6.9.0... (216.6MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/rav1e_bottle_manifest--0.8.1... (8.7KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/rav1e--0.8.1... (13.2MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/readline_bottle_manifest--8.2.13... (11.6KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/readline--8.2.13... (590.9KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/rubberband_bottle_manifest--4.0.0... (21.1KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/rubberband--4.0.0... (637.8KB)
# Removing: /opt/homebrew/Cellar/sdl2/2.32.8... (94 files, 6.7MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/sdl2_bottle_manifest--2.32.8... (21.9KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/sdl2--2.32.8... (1.8MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/snappy_bottle_manifest--1.2.2... (8.2KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/snappy--1.2.2... (46.9KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/speex_bottle_manifest--1.2.1... (13.4KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/speex--1.2.1... (549.8KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/sqlite_bottle_manifest--3.50.1... (11.4KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/sqlite--3.50.1... (2.3MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/srt_bottle_manifest--1.5.4... (11KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/srt--1.5.4... (1.8MB)
# Removing: /opt/homebrew/Cellar/svt-av1/3.0.2... (18 files, 3.4MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/svt-av1_bottle_manifest--3.0.2... (8.7KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/svt-av1--3.0.2... (1.4MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/swig_bottle_manifest--4.3.1... (10.1KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/swig--4.3.1... (1.7MB)
# Removing: /opt/homebrew/Cellar/theora/1.1.1... (98 files, 2.2MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/theora_bottle_manifest--1.1.1-4... (15.8KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/theora--1.1.1... (695.9KB)
# Removing: /opt/homebrew/Cellar/unbound/1.23.0... (59 files, 6.5MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/unbound_bottle_manifest--1.23.0... (16.3KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/unbound--1.23.0... (3MB)
# Removing: /opt/homebrew/Cellar/webp/1.5.0... (64 files, 2.7MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/webp_bottle_manifest--1.5.0... (16.2KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/webp--1.5.0... (904.6KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/wget_bottle_manifest--1.25.0... (14.2KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/wget--1.25.0... (1.6MB)
# Removing: /opt/homebrew/Cellar/x264/r3108... (12 files, 4.3MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/x264_bottle_manifest--r3108... (9.8KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/x264--r3108... (2.0MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/x265_bottle_manifest--4.1-1... (8.8KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/x265--4.1... (4.0MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/xorgproto_bottle_manifest--2024.1... (18.6KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/xorgproto--2024.1... (717.1KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/xvid_bottle_manifest--1.3.7... (13.1KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/xvid--1.3.7... (439.7KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/xz_bottle_manifest--5.8.1... (11.8KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/xz--5.8.1... (748.1KB)
# Removing: /opt/homebrew/Cellar/zeromq/4.3.5_1... (85 files, 6.7MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/zeromq_bottle_manifest--4.3.5_1-1... (9.8KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/zeromq--4.3.5_1... (1.7MB)
# Removing: /opt/homebrew/Cellar/zimg/3.0.5... (28 files, 1.2MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/zimg_bottle_manifest--3.0.5... (11.7KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/zimg--3.0.5... (355.3KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/zstd_bottle_manifest--1.5.7... (12.9KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/zstd--1.5.7... (785.5KB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/portable-ruby-3.4.5.arm64_big_sur.bottle.tar.gz... (12.1MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/portable-ruby-3.4.4.arm64_big_sur.bottle.tar.gz... (12.0MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/bootsnap/118b6dfb18563197d4ab01806eddb3405e8181f8c2dd7860c090a25be75be0f3... (645 files, 5.6MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/bootsnap/287d6b13bd97dfce385fd07e3348320940a44056e50552b059ee64db214471b8... (570 files, 5.0MB)
# Removing: /Users/sandeepjunnarkar/Library/Caches/Homebrew/bootsnap/b398a48f8ba83ea2e8b1f255b1e09c4ea8ed2874200563c348cc34030e67c441... (632 files, 5.3MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/cjson... (23 files, 261.8KB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/libtiff... (487 files, 9.0MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/libpng... (27 files, 1.4MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/frei0r... (163 files, 6.0MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/nettle... (95 files, 2.9MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/pixman... (10 files, 1.4MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/freetype... (67 files, 2.7MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/imath... (49 files, 987.8KB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/mpg123... (33 files, 2MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/libunistring... (58 files, 5.8MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/pango... (68 files, 3.7MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/openjpeg... (511 files, 14.7MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/highway... (80 files, 5.6MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/zimg... (27 files, 1.2MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/brotli... (32 files, 1.9MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/zeromq... (84 files, 6.7MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/harfbuzz... (76 files, 12.5MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/libbluray... (21 files, 1.2MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/glib... (503 files, 39.6MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/aom... (27 files, 10.6MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/libarchive... (64 files, 4MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/webp... (63 files, 2.6MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/svt-av1... (18 files, 3.5MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/libnghttp2... (13 files, 786.4KB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/openexr... (211 files, 5MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/fontconfig... (97 files, 1.6MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/libdeflate... (16 files, 334KB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/openssl@3... (7,608 files, 37.7MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/ca-certificates... (3 files, 239.2KB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/gettext... (2,427 files, 29.6MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/libmicrohttpd... (25 files, 1.6MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/dav1d... (15 files, 942KB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/openjph... (24 files, 629KB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/libssh... (24 files, 1.5MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/pcre2... (243 files, 7.3MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/leptonica... (54 files, 7.2MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/x264... (11 files, 4.4MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/jpeg-xl... (63 files, 36MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/unbound... (58 files, 6.6MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/theora... (125 files, 2.6MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/sdl2... (93 files, 6.7MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/icu4c@78... (278 files, 87.9MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/p11-kit... (32 files, 4.5MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/libudfread... (12 files, 154.8KB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/jpeg-turbo... (46 files, 3.7MB)
# Removing: /opt/homebrew/var/homebrew/tmp/.cellar/gnutls... (1,295 files, 12.0MB)
# Pruned 0 symbolic links and 2 directories from /opt/homebrew
# ==> Caveats
# ==> tesseract
# This formula contains only the "eng", "osd", and "snum" language data files.
# If you need any other supported languages, run `brew install tesseract-lang`.

# %%
## import libaries
import pandas as pd
import regex as re
import glob
from mangoCR import pdf2image_ocr_text

# %%
## glob some pdfs together
target_pdfs = glob.glob("md-excerpts/*pdf")
target_pdfs
# Out:
# ['md-excerpts/md-192582.pdf',
#  'md-excerpts/md-211807.pdf',
#  'md-excerpts/md-250497.pdf',
#  'md-excerpts/md-125202.pdf',
#  'md-excerpts/md-152712.pdf',
#  'md-excerpts/md-113372.pdf',
#  'md-excerpts/md-198793.pdf',
#  'md-excerpts/md-137421.pdf',
#  'md-excerpts/md-162447.pdf',
#  'md-excerpts/md-009178.pdf',
#  'md-excerpts/md-184714.pdf',
#  'md-excerpts/md-026201.pdf',
#  'md-excerpts/md-260373.pdf']

# %% [markdown]
# ### Single file analysis
#
# Let's see how it works on a single file before we iterate through all of them.

# %%
## convert pdf to text (not markdown)
# text = pdf2image_ocr_text(target_pdfs[-1])
# text

text = pdf2image_ocr_text(target_pdfs[-1])
text
# Out:
# Processing PDF 1 of 1: md-260373
#   - Processed page 1 of 17 in md-260373
#   - Processed page 2 of 17 in md-260373
#   - Processed page 3 of 17 in md-260373
#   - Processed page 4 of 17 in md-260373
#   - Processed page 5 of 17 in md-260373
#   - Processed page 6 of 17 in md-260373
#   - Processed page 7 of 17 in md-260373
#   - Processed page 8 of 17 in md-260373
#   - Processed page 9 of 17 in md-260373
#   - Processed page 10 of 17 in md-260373
#   - Processed page 11 of 17 in md-260373
#   - Processed page 12 of 17 in md-260373
#   - Processed page 13 of 17 in md-260373
#   - Processed page 14 of 17 in md-260373
#   - Processed page 15 of 17 in md-260373
#   - Processed page 16 of 17 in md-260373
#   - Processed page 17 of 17 in md-260373
# Finished processing md-260373
#
# All PDFs have been processed.
# '## md-260373_page_1\nNEW YoRK | Department\n\nSTATE OF\n\nOPPORTUNITY.\nof Health\nKATHY HOCHUL JAMES V. McDONALD, M.D, MPH. MEGAN £. BALDWIN\nGovernor Acting Commissioner Acting Executive Deputy Commissioner\n\nApril 25, 2023\n\nCERTIFIED MAIL-RETURN RECEIPT REQUESTED\n\nManish Raval, M.D.\n\nRe: License No. 260373\n\nDear Dr. Raval:\n\nEnclosed is a copy of the New York State Board for Professional Medical Conduct\n(BPMC) Order No. 23-086. This order and any penalty provided therein goes into effect\nMay 2, 2023.\n\nPlease direct any questions to: Board for Professional Medical Conduct, Riverview\nCenter, 150 Broadway, Suite 355, Albany, New York 12204, telephone # 518-402-0846.\n\nSincerely,\n\nDavid Besser, M.D.\nExecutive Secretary\nBoard for Professional Medical Conduct\n\nEnclosure\n\ncc: Concetta Lomanto, Esq.\nMaynard, O’Connor, Smith and Catalinotto, LLP.\n6 Tower Place\nAlbany, New York 12203\n\nEmpire State Plaza, Corning Tower, Albany, NY 12237 | health.ny.gov\n\n\n## md-260373_page_2\n[st Ie de eels\n\nNEW YORK STATE DEPARTMENT OF HEALTH\nSTATE BOARD FOR PROFESSIONAL MEDICAL CONDUCT\n\nASLEEP St 5\n\nBPMC No. 23-086\n{N THE MATTER °\n\nOF CONSENT\nMANISH RAVAL, M.D. ORDER Ho\n\nUpon the application of (Respondent) Manish Raval, M.D. in the attached Consent\n\nAgreement and Order, which is made a part of this Consent Order, it is\nORDERED, that the Consent Agreement, and its terms, are adopted and\n\nit is further\nORDERED, that this Consent Order shall be effective upon issuance by the Board,\neither\n\nby mailing of a copy of this Consent Order, either by first class mail fo Respondent at\nthe address in the attached Consent Agreement or by certified mail to Respondent\'s\n\nattorney, OR\n\nLee PpDEUMIINITIEe mi  eg\n\nupon facsimile transmission to Respondent or Respondent\'s attorney,\nwhichever is first.\n\n, SO ORDERED,\n\nDATE: 4/24/2023\n\nVice Chair\nState Board for Professional Medical Conduct i\n\n\n## md-260373_page_3\nNEW YORK STATE DEPARTMENT OF HEALTH\nSTATE BOARD FOR PROFESSIONAL MEDICAL CONDUCT\n\nIN THE MATTER\n\nOF CONSENT\n\nAGREEMENT\n\nMANISH RAVAL, M.D.\n\nManish Raval, M.D., represents that all of the following statements are frue:\n\nThat on or about February 10, 2011, | was licensed to practice asa physician in the\n\nState of New York and issued License No. 260373 by the New York State Education\n\nDepartment.\n\nMy current adress (A\n\nand | will advise the Director of the Office of Professional Medical Conduct of any change\n\nof address,\n\n| understand that the New York State Board for Professional.Medical\nConduct (Board) has charged me with ons or more specifications of professional\nmisconduct, as set forth in a Statement of Charges, marked as Exhibit "A", attached to and\n\npart of this Consent Agreement.\n\n| assert that | cannot successfully defend against at least one act of misconduct\n\nalleged, in full satisfaction of the charges against me, and agree to the following penalty:\n\na LBs\n\neon Me\nRe\na)\n\nfom setae\n\nSif\n\nfeaiiegasheers eer\n\neasy nie:\n\n: rr lyons\n\nad\n\nPaes\n\n\n## md-260373_page_4\n* Pursuant to New York Pub. Health Law § 230-a(2), my license to practice medicine\n\nin New York State shall be suspended for three years _, with the entire period\nstayed.\n» Pursuant to New York Pub. Health Law § 230-a(9), | shall be placed on probation\nfor _three years_, subject to the terms set forth in attached Exhibit “B.”\n¢ Pursuant to N.Y. Pub. Health Law § 230-a(3), my license to practice medicine in\nNew York State shall be limited as follows:\n* | shall be permitted to prescribe a five (5) day supply of controlled\nsubstances to patients of St. Luke’s Cornwall Hospital and/or Vassar\nBrothers Hospital; and\n« {shall be permitted to prescribe suboxone and/or issue certifications\nand/or recertifications for medical marijuana in a non-hospital setting,\nwhile under the supervision of a practice supervisor, at the elbow, as\nset forth in attached Exhibit “ ...

# %% [markdown]
# ### Keyword Context Finder
#
# https://pypi.org/project/fuzzy-context-finder/

# %%
pip install fuzzy-context-finder
# Out:
# Requirement already satisfied: fuzzy-context-finder in /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/lib/python3.9/site-packages (0.1.2)
# Requirement already satisfied: regex in /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/lib/python3.9/site-packages (from fuzzy-context-finder) (2025.10.23)
# Requirement already satisfied: pandas>=1.0.0 in /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/lib/python3.9/site-packages (from fuzzy-context-finder) (2.3.2)
# Requirement already satisfied: rapidfuzz>=2.0.0 in /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/lib/python3.9/site-packages (from fuzzy-context-finder) (3.13.0)
# Requirement already satisfied: numpy>=1.22.4 in /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/lib/python3.9/site-packages (from pandas>=1.0.0->fuzzy-context-finder) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/lib/python3.9/site-packages (from pandas>=1.0.0->fuzzy-context-finder) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/lib/python3.9/site-packages (from pandas>=1.0.0->fuzzy-context-finder) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/lib/python3.9/site-packages (from pandas>=1.0.0->fuzzy-context-finder) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->fuzzy-context-finder) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
## import the package
from fuzzy_context_finder import keyword_context_finder

# %%
keywords
# Out:
# ['opioid',
#  'prescription',
#  'sexual',
#  'abuse',
#  'assault',
#  'unlawful',
#  'fraud',
#  'controlled substances']

# %%
## create df
df = keyword_context_finder(text, keywords, "md-excerpts/md-260373.pdf", match_threshold=75)
df
# Out:
#                    File Name        Page Marker  Page Number  Matched Term  \
# 0  md-excerpts/md-260373.pdf   md-260373_page_5            5  prescribing,
# 1  md-excerpts/md-260373.pdf   md-260373_page_5            5           use
# 2  md-excerpts/md-260373.pdf   md-260373_page_7            7   description
# 3  md-excerpts/md-260373.pdf  md-260373_page_15           15   prescribing
# 4  md-excerpts/md-260373.pdf  md-260373_page_15           15         cause
# 5  md-excerpts/md-260373.pdf  md-260373_page_17           17  prescribing,
# 6  md-excerpts/md-260373.pdf  md-260373_page_17           17  prescribing,
# 7  md-excerpts/md-260373.pdf  md-260373_page_17           17   prescribing
# 8  md-excerpts/md-260373.pdf  md-260373_page_17           17         cause
# 9  md-excerpts/md-260373.pdf  md-260373_page_17           17   prescribing
#
#   Original Term  Similarity Score  \
# 0  prescription         75.000000
# 1         abuse         75.000000
# 2  prescription         86.956522
# 3  prescription         78.260870
# 4         abuse         80.000000
# 5  prescription         75.000000
# 6  prescription         75.000000
# 7  prescription         78.260870
# 8         abuse         80.000000
# 9  prescription         78.260870
#
#                    Search Term with 50 Words Context  \
# 0  while under the supervision of a practice supe...
# 1  exceptions noted above, shall be appropriately...
# 2  Center, 150 Broadway, Suite 355, Albany, New Y...
# 3  on a random unannounced basis at least monthly...
# 4  to OPMC. b) Respondent shall be solely respons...
# 5  in Paragraphs a-c below. Regardless of the rea...
# 6  In that event, Respondent shall propose anothe...
# 7  probation, and willing to report to OPMC, Resp...
# 8  report to OPMC, Respondent shall ensure that t...
# 9  shail authorize the practice supervisor to hav...
#
#                  Previous 250 Words (Including Term)  \
# 0  * Pursuant to New York Pub. Health Law § 230-a...
# 1  * Pursuant to New York Pub. Health Law § 230-a...
# 2  the licensee's registration period. Licensee s...
# 3  specialty, (“practice monitor’) proposed by Re...
# 4  Respondent shall have an approved successor in...
# 5  1) EXHIBIT “C” PRACTICE SUPERVISOR No more tha...
# 6  1) EXHIBIT “C” PRACTICE SUPERVISOR No more tha...
# 7  for cause, which shall include but not be limi...
# 8  include but not be limited to the inadequacy o...
# 9  if the Director does not approve Respondent's ...
#
#                      Next 250 Words (Including Term)
# 0  prescribing, dispensing, ordering and/or admin...
# 1  use of controlled substances, upon execution o...
# 2  description of Respondent's employment and pra...
# 3  prescribing information and office records. Th...
# 4  cause the practice monitor to report quarterly...
# 5  prescribing, ordering, dispensing and/or admin...
# 6  prescribing, ordering, dispensing and/or admin...
# 7  prescribing practice. Respondent shall cause t...
# 8  cause the practice supervisor to report within...
# 9         prescribing practice. These narrative Bev,

# %% [markdown]
# ## Hard to read text?
#
# We'll tap a package called <a href="https://pypi.org/project/tabular-2-text/">tabular_2_text</a>.

# %%
pip install tabular-2-text
# Out:
# Requirement already satisfied: tabular-2-text in /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/lib/python3.9/site-packages (0.1.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/lib/python3.9/site-packages (from tabular-2-text) (2.0.2)
# Requirement already satisfied: pandas>=1.3.0 in /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/lib/python3.9/site-packages (from tabular-2-text) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/lib/python3.9/site-packages (from pandas>=1.3.0->tabular-2-text) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/lib/python3.9/site-packages (from pandas>=1.3.0->tabular-2-text) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/lib/python3.9/site-packages (from pandas>=1.3.0->tabular-2-text) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->tabular-2-text) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: /Users/sandeepjunnarkar/dataProjects/notebook-test-1/.venv/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
## import package
from tabular_2_text  import tab2text

# %%
## convert to text
tab2text(df, "doc_text.txt")
# Out:
# doc_text.txt is in your local project folder.
# 'doc_text.txt'

# %% [markdown]
# ## Now iterate through all files

# %%
## iterate through files

# %%
## how long is df_list?

# %%
## concat them

# %%
## get info

# %%
## convert to text
